# %% [markdown]
# <a href="https://colab.research.google.com/github/sejaldb/computer-vision_internship/blob/main/video_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install ffmpeg
# !apt-get install -y ffmpeg

# %%
#displaying input video
from IPython.display import Video
Video('/content/input1.mp4', embed=True,width=600, height=400)

# %%
#converting video to images (30 frames per second)
# !ffmpeg -i input1.mp4 -r 30 frame%d.png

# %%
#installing ultralytics for image detection/segmentation and importing required files
# !pip install ultralytics
import ultralytics

# %%
#object segmentation of multiple images is done using yolo8s
# !yolo predict task=segment model=yolov8s-seg.onnx source="/content"

# %%
#converting segmented multiple images back into a video using ffmpeg
# !ffmpeg -framerate 30 -i /content/runs/segment/predict/frame%d.jpg -c:v libx264 -pix_fmt yuv420p output1.mp4

# %%
#displaying output video
from IPython.display import Video
Video('/content/output1.mp4', embed=True,width=600, height=400)
